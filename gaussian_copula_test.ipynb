# %% [markdown]
# # Full-run test for Gaussian Copula
#
# This notebook provides runnable cells to perform full training runs for `CTGAN`, `TabDDPM`, and `TabSyn` using the project `TrainTestSplitPipeline`.
#
# Notes:
# - The notebook defaults to skipping the pipeline TSTR evaluations (these import `xgboost`) to avoid extra dependency installs. Set `SKIP_EVALUATIONS = False` if you have `xgboost` installed and want full evaluation.
# - Adjust the model config dictionaries below to control epochs / steps / batch sizes for real full runs.
# - Each cell is annotated so you can run the cells interactively per dataset/model.

# %%
pip install sdv
# Out:
# Requirement already satisfied: sdv in c:\users\lbrum\anaconda3\lib\site-packages (1.32.1)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (1.42.26)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (1.42.26)
# Requirement already satisfied: cloudpickle>=2.1.0 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (3.0.0)
# Requirement already satisfied: graphviz>=0.13.2 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (1.26.4)
# Requirement already satisfied: pandas>=2.1.1 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (2.2.2)
# Requirement already satisfied: tqdm>=4.29 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (4.66.5)
# Requirement already satisfied: copulas>=0.12.1 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (0.13.0)
# Requirement already satisfied: ctgan>=0.11.1 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (0.11.1)
# Requirement already satisfied: deepecho>=0.7.0 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.18.2 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (1.19.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (0.25.0)
# Requirement already satisfied: platformdirs>=4.0 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (4.5.1)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\lbrum\anaconda3\lib\site-packages (from sdv) (6.0.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\lbrum\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\lbrum\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.28->sdv) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\lbrum\anaconda3\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\lbrum\anaconda3\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.2.3)
# Requirement already satisfied: plotly>=5.10.0 in c:\users\lbrum\anaconda3\lib\site-packages (from copulas>=0.12.1->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.12.0 in c:\users\lbrum\anaconda3\lib\site-packages (from copulas>=0.12.1->sdv) (1.17.0)
# Requirement already satisfied: torch>=2.3.0 in c:\users\lbrum\anaconda3\lib\site-packages (from ctgan>=0.11.1->sdv) (2.7.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lbrum\anaconda3\lib\site-packages (from pandas>=2.1.1->sdv) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lbrum\anaconda3\lib\site-packages (from pandas>=2.1.1->sdv) (2023.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\lbrum\anaconda3\lib\site-packages (from rdt>=1.18.2->sdv) (1.5.1)
# Requirement already satisfied: Faker!=37.11.0,>=17 in c:\users\lbrum\anaconda3\lib\site-packages (from rdt>=1.18.2->sdv) (40.1.0)
# Requirement already satisfied: colorama in c:\users\lbrum\anaconda3\lib\site-packages (from tqdm>=4.29->sdv) (0.4.6)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lbrum\anaconda3\lib\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (8.2.3)
# Requirement already satisfied: packaging in c:\users\lbrum\anaconda3\lib\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (24.1)
# Requirement already satisfied: six>=1.5 in c:\users\lbrum\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lbrum\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lbrum\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (3.5.0)
# Requirement already satisfied: filelock in c:\users\lbrum\anaconda3\lib\site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lbrum\anaconda3\lib\site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lbrum\anaconda3\lib\site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (1.13.3)
# Requirement already satisfied: networkx in c:\users\lbrum\anaconda3\lib\site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lbrum\anaconda3\lib\site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\lbrum\anaconda3\lib\site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\lbrum\anaconda3\lib\site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lbrum\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lbrum\anaconda3\lib\site-packages (from jinja2->torch>=2.3.0->ctgan>=0.11.1->sdv) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports and helpers
import os
import importlib
import traceback
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

def ensure(path):
    os.makedirs(path, exist_ok=True)

# Convenience wrapper to create a pipeline that optionally disables evaluations
def make_pipeline(model_callable, skip_evaluations=True, evaluations=None):
    if skip_evaluations:
        return TrainTestSplitPipeline(model=model_callable, evaluations=[], override_evaluations=True)
    elif evaluations is not None:
        return TrainTestSplitPipeline(model=model_callable, evaluations=evaluations, override_evaluations=True)
    else:
        return TrainTestSplitPipeline(model=model_callable)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\lbrum\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\lbrum\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\lbrum\anaconda3\lib\site-packages (from xgboost) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# User configuration: choose dataset(s) and run options
DATASETS = ['adult', 'car', 'magic', 'nursery', 'shuttle']
SKIP_EVALUATIONS = True

# Top-level dirs
ensure('discretized_data')
ensure('sample_data')
ensure('synthetic')
ensure('Results')

MODEL_MAP = {
    'gaussian_copula': ('katabatic.models.gaussian_copula.models', 'GaussianCopulaModel'),
}

GAUSSIAN_COPULA_CONFIG = {
    'default_distribution': 'beta',
    'enforce_min_max_values': True,
    'enforce_rounding': True,
}

# %% [markdown]
# ## Preprocess datasets (run once)
# Run this cell to discretize the raw CSVs into `discretized_data/{dataset}.csv`.

# %%
for dataset in DATASETS:
    print('\n' + '='*60)
    print(f'Preprocessing {dataset}...')
    try:
        discretize_preprocess(file_path=f'raw_data/{dataset}.csv', output_path=f'discretized_data/{dataset}.csv', bins=10, strategy='uniform')
        print(f'Discretized -> discretized_data/{dataset}.csv')
    except Exception as e:
        print(f'Failed to preprocess {dataset}: {e}')
        import traceback; traceback.print_exc()
# Out:
# ============================================================
# Preprocessing adult...
# Preprocessing: raw_data/adult.csv
# Saved preprocessed discrete dataset to: discretized_data/adult.csv
# Discretized -> discretized_data/adult.csv
#
# ============================================================
# Preprocessing car...
# Preprocessing: raw_data/car.csv
# Saved preprocessed discrete dataset to: discretized_data/car.csv
# Discretized -> discretized_data/car.csv
#
# ============================================================
# Preprocessing magic...
# Preprocessing: raw_data/magic.csv
# Saved preprocessed discrete dataset to: discretized_data/magic.csv
# Discretized -> discretized_data/magic.csv
#
# ============================================================
# Preprocessing nursery...
# Preprocessing: raw_data/nursery.csv
# Saved preprocessed discrete dataset to: discretized_data/nursery.csv
# Discretized -> discretized_data/nursery.csv
#
# ============================================================
# Preprocessing shuttle...
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv
# Discretized -> discretized_data/shuttle.csv

# %% [markdown]
# ## Run full gaussian_copula
# This cell runs CTGAN for each selected dataset using `CTGAN_CONFIG` above. Be patient — full training can take time depending on `epochs` and dataset size.

# %%
for dataset in DATASETS:
    print('\n' + '='*60)
    print(f'Gaussian Copula -> {dataset}')
    synth_dir = os.path.join('synthetic', dataset, 'gaussian_copula')
    ensure(synth_dir)
    try:
        mod_path, cls_name = MODEL_MAP['gaussian_copula']
        module = importlib.import_module(mod_path)
        ModelClass = getattr(module, cls_name)
        model_factory = lambda: ModelClass(**GAUSSIAN_COPULA_CONFIG)
        pipeline = make_pipeline(model_factory, skip_evaluations=SKIP_EVALUATIONS)
        result = pipeline.run(
            input_csv=f'discretized_data/{dataset}.csv',
            output_dir=f'sample_data/{dataset}',
            synthetic_dir=synth_dir,
            real_test_dir=f'sample_data/{dataset}'
        )
        print('Gaussian Copula finished for', dataset)
    except Exception as e:
        print('Gaussian Copula failed for', dataset, e)
        import traceback; traceback.print_exc()
# Out:
# ============================================================
# Gaussian Copula -> adult
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [GaussianCopula] Creating metadata...
# [GaussianCopula] Initializing Gaussian Copula...
# [GaussianCopula] Fitting to 26048 samples...
# [GaussianCopula] Finished fitting in 46.94 seconds.
# [GaussianCopula] Generating 26048 synthetic samples...
# [GaussianCopula] Synthetic data saved:
#   X -> synthetic\adult\gaussian_copula\x_synth.csv
#   y -> synthetic\adult\gaussian_copula\y_synth.csv
#
# Results saved to: Results\adult\gaussian_copula_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.7807
#
# MLP:
# Accuracy: 0.7660
# F1 Score: 0.6825
# AUC: 0.7582
#
# RF:
# Accuracy: 0.7588
# F1 Score: 0.6909
# AUC: 0.7132
#
# XGBoost:
# Accuracy: 0.6923
# F1 Score: 0.7127
# AUC: 0.7311
# Gaussian Copula finished for adult
#
# ============================================================
# Gaussian Copula -> car
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [GaussianCopula] Creating metadata...
# [GaussianCopula] Initializing Gaussian Copula...
# [GaussianCopula] Fitting to 1382 samples...
# [GaussianCopula] Finished fitting in 2.22 seconds.
# [GaussianCopula] Generating 1382 synthetic samples...
# [GaussianCopula] Synthetic data saved:
#   X -> synthetic\car\gaussian_copula\x_synth.csv
#   y -> synthetic\car\gaussian_copula\y_synth.csv
#
# Results saved to: Results\car\gaussian_copula_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6965
# F1 Score: 0.5794
#
# RF:
# Accuracy: 0.6156
# F1 Score: 0.5787
#
# XGBoost:
# Accuracy: 0.6040
# F1 Score: 0.5839
# Gaussian Copula finished for car
#
# ============================================================
# Gaussian Copula -> magic
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# [GaussianCopula] Creating metadata...
# [GaussianCopula] Initializing Gaussian Copula...
# [GaussianCopula] Fitting to 15216 samples...
# [GaussianCopula] Finished fitting in 8.43 seconds.
# [GaussianCopula] Generating 15216 synthetic samples...
# [GaussianCopula] Synthetic data saved:
#   X -> synthetic\magic\gaussian_copula\x_synth.csv
#   y -> synthetic\magic\gaussian_copula\y_synth.csv
#
# Results saved to: Results\magic\gaussian_copula_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6748
# F1 Score: 0.5677
# AUC: 0.5841
#
# MLP:
# Accuracy: 0.6485
# F1 Score: 0.5571
# AUC: 0.5634
#
# RF:
# Accuracy: 0.5889
# F1 Score: 0.5687
# AUC: 0.5575
#
# XGBoost:
# Accuracy: 0.5620
# F1 Score: 0.5666
# AUC: 0.5000
# Gaussian Copula finished for magic
#
# ============================================================
# Gaussian Copula -> nursery
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# [GaussianCopula] Creating metadata...
# [GaussianCopula] Initializing Gaussian Copula...
# [GaussianCopula] Fitting to 10368 samples...
# [GaussianCopula] Finished fitting in 3.55 seconds.
# [GaussianCopula] Generating 10368 synthetic samples...
# [GaussianCopula] Synthetic data saved:
#   X -> synthetic\nursery\gaussian_copula\x_synth.csv
#   y -> synthetic\nursery\gaussian_copula\y_synth.csv
#
# Results saved to: Results\nursery\gaussian_copula_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.5883
# F1 Score: 0.5836
#
# MLP:
# Accuracy: 0.5664
# F1 Score: 0.5400
#
# RF:
# Accuracy: 0.4799
# F1 Score: 0.4728
#
# XGBoost:
# Accuracy: 0.5127
# F1 Score: 0.5022
# Gaussian Copula finished for nursery
#
# ============================================================
# Gaussian Copula -> shuttle
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# [GaussianCopula] Creating metadata...
# [GaussianCopula] Initializing Gaussian Copula...
# [GaussianCopula] Fitting to 46400 samples...
# [GaussianCopula] Finished fitting in 30.06 seconds.
# [GaussianCopula] Generating 46400 synthetic samples...
# [GaussianCopula] Synthetic data saved:
#   X -> synthetic\shuttle\gaussian_copula\x_synth.csv
#   y -> synthetic\shuttle\gaussian_copula\y_synth.csv
#
# Results saved to: Results\shuttle\gaussian_copula_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# MLP:
# Accuracy: 0.7903
# F1 Score: 0.7025
#
# RF:
# Accuracy: 0.7665
# F1 Score: 0.7019
#
# XGBoost:
# Accuracy: 0.8069
# F1 Score: 0.7413
# Gaussian Copula finished for shuttle
