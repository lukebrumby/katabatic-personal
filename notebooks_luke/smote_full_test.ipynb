# %% [markdown]
# # Full-run test for SMOTE
#
# This notebook provides runnable cells to perform a full training run for 'SMOTE' using the project `TrainTestSplitPipeline`.
#
# Notes:
# - The notebook defaults to skipping the pipeline TSTR evaluations (these import `xgboost`) to avoid extra dependency installs. Set `SKIP_EVALUATIONS = False` if you have `xgboost` installed and want full evaluation.
# - Adjust the model config dictionaries below to control epochs / steps / batch sizes for real full runs.
# - Each cell is annotated so you can run the cells interactively per dataset/model.

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\lbrum\anaconda3\lib\site-packages (0.12.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.17.3 in c:\users\lbrum\anaconda3\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\lbrum\anaconda3\lib\site-packages (from imbalanced-learn) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\lbrum\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lbrum\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lbrum\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
# Imports and helpers
import os
import importlib
import traceback
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

def ensure(path):
    os.makedirs(path, exist_ok=True)

# Convenience wrapper to create a pipeline that optionally disables evaluations
def make_pipeline(model_callable, skip_evaluations=True, evaluations=None):
    if skip_evaluations:
        return TrainTestSplitPipeline(model=model_callable, evaluations=[], override_evaluations=True)
    elif evaluations is not None:
        return TrainTestSplitPipeline(model=model_callable, evaluations=evaluations, override_evaluations=True)
    else:
        return TrainTestSplitPipeline(model=model_callable)

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\lbrum\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\lbrum\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\lbrum\anaconda3\lib\site-packages (from xgboost) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# User configuration: choose dataset(s) and run options
DATASETS = ['adult', 'car', 'magic', 'nursery', 'shuttle']
SKIP_EVALUATIONS = True

# Top-level dirs
ensure('discretized_data')
ensure('sample_data')
ensure('synthetic')
ensure('Results')

MODEL_MAP = {
    # ... existing models ...
    'smote': ('katabatic.models.smote.models', 'SMOTEModel'),  # NEW
}

SMOTE_CONFIG = {
    'k_neighbors': 5,
    'sampling_strategy': 'auto',  # Balance all classes
    'random_state': 42,
}

# %% [markdown]
# ## Preprocess datasets (run once)
# Run this cell to discretize the raw CSVs into `discretized_data/{dataset}.csv`.

# %%
for dataset in DATASETS:
    print('\n' + '='*60)
    print(f'Preprocessing {dataset}...')
    try:
        discretize_preprocess(file_path=f'raw_data/{dataset}.csv', output_path=f'discretized_data/{dataset}.csv', bins=10, strategy='uniform')
        print(f'Discretized -> discretized_data/{dataset}.csv')
    except Exception as e:
        print(f'Failed to preprocess {dataset}: {e}')
        import traceback; traceback.print_exc()
# Out:
# ============================================================
# Preprocessing adult...
# Preprocessing: raw_data/adult.csv
# Saved preprocessed discrete dataset to: discretized_data/adult.csv
# Discretized -> discretized_data/adult.csv
#
# ============================================================
# Preprocessing car...
# Preprocessing: raw_data/car.csv
# Saved preprocessed discrete dataset to: discretized_data/car.csv
# Discretized -> discretized_data/car.csv
#
# ============================================================
# Preprocessing magic...
# Preprocessing: raw_data/magic.csv
# Saved preprocessed discrete dataset to: discretized_data/magic.csv
# Discretized -> discretized_data/magic.csv
#
# ============================================================
# Preprocessing nursery...
# Preprocessing: raw_data/nursery.csv
# Saved preprocessed discrete dataset to: discretized_data/nursery.csv
# Discretized -> discretized_data/nursery.csv
#
# ============================================================
# Preprocessing shuttle...
# Preprocessing: raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: discretized_data/shuttle.csv
# Discretized -> discretized_data/shuttle.csv

# %% [markdown]
# ## Run full SMOTE
# This cell runs CTGAN for each selected dataset using `CTGAN_CONFIG` above. Be patient — full training can take time depending on `epochs` and dataset size.

# %%
for dataset in DATASETS:
    print('\n' + '='*60)
    print(f'SMOTE -> {dataset}')
    synth_dir = os.path.join('synthetic', dataset, 'smote')
    ensure(synth_dir)
    try:
        mod_path, cls_name = MODEL_MAP['smote']
        module = importlib.import_module(mod_path)
        ModelClass = getattr(module, cls_name)
        model_factory = lambda: ModelClass(**SMOTE_CONFIG)
        pipeline = make_pipeline(model_factory, skip_evaluations=SKIP_EVALUATIONS)
        result = pipeline.run(
            input_csv=f'discretized_data/{dataset}.csv',
            output_dir=f'sample_data/{dataset}',
            synthetic_dir=synth_dir,
            real_test_dir=f'sample_data/{dataset}'  # ← ADD THIS LINE!
        )
        print('SMOTE finished for', dataset)
    except Exception as e:
        print('SMOTE failed for', dataset, e)
        import traceback; traceback.print_exc()
# Out:
# ============================================================
# SMOTE -> adult
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [SMOTE] Initializing with k_neighbors=5...
# [SMOTE] Ready to generate samples from 26048 training samples...
# [SMOTE] Generated samples in 0.88 seconds.
# [SMOTE] Generated 13502 new synthetic samples...
# [SMOTE] Returning 26048 total samples (original size with balanced classes)...
# [SMOTE] Synthetic data saved:
#   X -> synthetic\adult\smote\x_synth.csv
#   y -> synthetic\adult\smote\y_synth.csv
#
# Results saved to: Results\adult\smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7436
# F1 Score: 0.7599
# AUC: 0.8380
#
# MLP:
# Accuracy: 0.7910
# F1 Score: 0.8035
# AUC: 0.8911
#
# RF:
# Accuracy: 0.8115
# F1 Score: 0.8191
# AUC: 0.8722
#
# XGBoost:
# Accuracy: 0.8067
# F1 Score: 0.8169
# AUC: 0.8981
# SMOTE finished for adult
#
# ============================================================
# SMOTE -> car
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [SMOTE] Initializing with k_neighbors=5...
# [SMOTE] Ready to generate samples from 1382 training samples...
# [SMOTE] Generated samples in 0.02 seconds.
# [SMOTE] Generated 2490 new synthetic samples...
# [SMOTE] Returning 1382 total samples (original size with balanced classes)...
# [SMOTE] Synthetic data saved:
#   X -> synthetic\car\smote\x_synth.csv
#   y -> synthetic\car\smote\y_synth.csv
#
# Results saved to: Results\car\smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.5578
# F1 Score: 0.6022
#
# MLP:
# Accuracy: 0.9451
# F1 Score: 0.9462
#
# RF:
# Accuracy: 0.9595
# F1 Score: 0.9600
#
# XGBoost:
# Accuracy: 0.9913
# F1 Score: 0.9914
# SMOTE finished for car
#
# ============================================================
# SMOTE -> magic
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# [SMOTE] Initializing with k_neighbors=5...
# [SMOTE] Ready to generate samples from 15216 training samples...
# [SMOTE] Generated samples in 0.56 seconds.
# [SMOTE] Generated 4516 new synthetic samples...
# [SMOTE] Returning 15216 total samples (original size with balanced classes)...
# [SMOTE] Synthetic data saved:
#   X -> synthetic\magic\smote\x_synth.csv
#   y -> synthetic\magic\smote\y_synth.csv
#
# Results saved to: Results\magic\smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7834
# F1 Score: 0.7859
# AUC: 0.8487
#
# MLP:
# Accuracy: 0.8467
# F1 Score: 0.8468
# AUC: 0.9071
#
# RF:
# Accuracy: 0.8252
# F1 Score: 0.8264
# AUC: 0.8892
#
# XGBoost:
# Accuracy: 0.8475
# F1 Score: 0.8477
# AUC: 0.9099
# SMOTE finished for magic
#
# ============================================================
# SMOTE -> nursery
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# [SMOTE] Warning: Smallest class has 2 samples.
# [SMOTE] Adjusting k_neighbors from 5 to 1
# [SMOTE] Initializing with k_neighbors=1...
# [SMOTE] Ready to generate samples from 10368 training samples...
# [SMOTE] Generated samples in 0.13 seconds.
# [SMOTE] Generated 6912 new synthetic samples...
# [SMOTE] Returning 10368 total samples (original size with balanced classes)...
# [SMOTE] Synthetic data saved:
#   X -> synthetic\nursery\smote\x_synth.csv
#   y -> synthetic\nursery\smote\y_synth.csv
#
# Results saved to: Results\nursery\smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7157
# F1 Score: 0.7260
#
# MLP:
# Accuracy: 0.9807
# F1 Score: 0.9807
#
# RF:
# Accuracy: 0.9688
# F1 Score: 0.9686
#
# XGBoost:
# Accuracy: 0.9981
# F1 Score: 0.9983
# SMOTE finished for nursery
#
# ============================================================
# SMOTE -> shuttle
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# [SMOTE] Initializing with k_neighbors=5...
# [SMOTE] Ready to generate samples from 46400 training samples...
# [SMOTE] Generated samples in 0.73 seconds.
# [SMOTE] Generated 208883 new synthetic samples...
# [SMOTE] Returning 46400 total samples (original size with balanced classes)...
# [SMOTE] Synthetic data saved:
#   X -> synthetic\shuttle\smote\x_synth.csv
#   y -> synthetic\shuttle\smote\y_synth.csv
#
# Results saved to: Results\shuttle\smote_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.9478
# F1 Score: 0.9511
#
# MLP:
# Accuracy: 0.9990
# F1 Score: 0.9990
#
# RF:
# Accuracy: 0.9993
# F1 Score: 0.9993
#
# XGBoost:
# Accuracy: 0.9991
# F1 Score: 0.9991
# SMOTE finished for shuttle
